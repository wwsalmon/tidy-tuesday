// %%
fs = require("fs");
dataMaleRaw = fs.readFileSync("male.json", "utf-8");
dataMale = JSON.parse(dataMaleRaw);
dataFemaleRaw = fs.readFileSync("female.json", "utf-8");
dataFemale = JSON.parse(dataFemaleRaw);
// Out:
// [
//   { year: 1880, sex: 'F', name: 'Mary', n: 7065, prop: 0.07238359 },
//   { year: 1880, sex: 'F', name: 'Anna', n: 2604, prop: 0.02667896 },
//   { year: 1880, sex: 'F', name: 'Emma', n: 2003, prop: 0.02052149 },
//   {
//     year: 1880,
//     sex: 'F',
//     name: 'Elizabeth',
//     n: 1939,
//     prop: 0.01986579
//   },
//   { year: 1880, sex: 'F', name: 'Minnie', n: 1746, prop: 0.01788843 },
//   { year: 1880, sex: 'F', name: 'Margaret', n: 1578, prop: 0.0161672 },
//   { year: 1880, sex: 'F', name: 'Ida', n: 1472, prop: 0.01508119 },
//   { year: 1880, sex: 'F', name: 'Alice', n: 1414, prop: 0.01448696 },
//   { year: 1880, sex: 'F', name: 'Bertha', n: 1320, prop: 0.0135239 },
//   { year: 1880, sex: 'F', name: 'Sarah', n: 1288, prop: 0.01319605 },
//   { year: 1880, sex: 'F', name: 'Annie', n: 1258, prop: 0.01288868 },
//   { year: 1880, sex: 'F', name: 'Clara', n: 1226, prop: 0.01256083 },
//   { year: 1880, sex: 'F', name: 'Ella', n: 1156, prop: 0.01184366 },
// ...

// %%
uniqueMaleNames = [...new Set(dataMale.map(d => d.name))];
maleNameCounts = uniqueMaleNames
    .map(d => ({name: d, count: dataMale.filter(x => x.name === d).reduce((a, b) => a + b.count, 0)}));

// %%
uniqueMaleNames = [...new Set(dataMale.map(d => d.name))];
