# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_raw = pd.read_csv("../stations.csv")
# Out:
# C:\Users\wwsam\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\IPython\core\interactiveshell.py:3340: DtypeWarning: Columns (9,18,19,23,34,36,37,46,49,52,55,56,60,61,62,63,64,65) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df_raw.describe()
# Out:
#                   X             Y      OBJECTID  PLUS4  EV_LEVEL1_EVSE_NUM  \
# count  59927.000000  59927.000000  59927.000000    0.0         1003.000000
# mean     -97.729076     37.752821  29964.000000    NaN            3.367896
# std       18.997244      5.012616  17299.579128    NaN            7.272652
# min     -159.788556      0.000000      1.000000    NaN            1.000000
# 25%     -118.027879     34.029061  14982.500000    NaN            1.000000
# 50%      -94.572079     38.076412  29964.000000    NaN            1.000000
# 75%      -80.822796     41.381453  44945.500000    NaN            2.000000
# max        0.000000     64.852466  59927.000000    NaN           90.000000
#
#        EV_LEVEL2_EVSE_NUM  EV_DC_FAST_COUNT      LATITUDE     LONGITUDE  \
# count        44762.000000       5905.000000  59927.000000  59927.000000
# mean             2.312855          3.739881     37.754624    -97.731622
# std              3.264666          4.324265      5.005829     18.994369
# ...

# %%
df_locs = df_raw[["X", "Y"]].copy()

# %%
df_locs.to_json("../locs.json", orient="records")
